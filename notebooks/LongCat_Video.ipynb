# %% [markdown]
# # **Clone**

# %%
# %cd /root
# !git clone https://github.com/meituan-longcat/LongCat-Video
# %cd LongCat-Video

# %% [markdown]
# # **Requirements**

# %%
# %uv pip install torch==2.6.0+cu124 torchvision==0.21.0+cu124 torchaudio==2.6.0 --index-url https://download.pytorch.org/whl/cu124

# %uv pip install ninja psutil packaging

# %uv pip install flash_attn==2.7.4.post1 --no-build-isolation

# %uv pip install -r requirements.txt --no-build-isolation

# %% [markdown]
# # **ffmpeg**

# %%
# !apt-get -y update
# !apt-get install -y libglib2.0-0 libgl1
# !apt-get install -y ffmpeg

# %% [markdown]
# # **Models**

# %%
# !pip install "huggingface_hub[cli]"
# !huggingface-cli download meituan-longcat/LongCat-Video --local-dir ./weights/LongCat-Video

# %% [markdown]
# # **Text to Video**

# %%
# !torchrun run_demo_text_to_video.py --checkpoint_dir=./weights/LongCat-Video --enable_compile

# %% [markdown]
# # **Long Text to Video**

# %%
# !torchrun run_demo_long_video.py --checkpoint_dir=./weights/LongCat-Video --enable_compile

# %% [markdown]
# # **Image to Video**

# %%
# !torchrun run_demo_image_to_video.py --checkpoint_dir=./weights/LongCat-Video --enable_compile
